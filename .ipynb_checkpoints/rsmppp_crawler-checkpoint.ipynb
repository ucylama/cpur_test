# %% [markdown]
# #### ОГЛАВЛЕНИЕ

# %% [markdown]
# 1. [Подготовка среды и изучение содержания данных](#0.0)
#     * [Установка необходимых библиотек](#1)
#     * [Загрузка файлов](#2)
#     * [Валидация xml-файлов и xsd-схемы](#3)
#     * [Визуальное знакомство со структурой полученных файлов](#4)
#
#
# 2. [Архитектура БД в PostgreSQL](#0.1)
#     * [Подключение к Базе данных PostgreSQL](#5)
#     * [Описание структуры БД](#6)
#     * [Создание необходимых таблиц в Базе данных](#7)
#
#
# 3. [Подготовка и парсинг данных в Базу данных](#0.2)
#     * [Функции для запросов на добавление данных в БД](#8)
#     * [Функции для парсинга данных из xml-файлов и добавления их в БД](#9)
#     * [Парсинг данных из xlm-файлов в БД](#10)
# ____

# %% [markdown]
# ## Подготовка среды и изучение содержания данных <a name=‘0.0’></a>

# %% [markdown]
# ### Установка необходимых библиотек <a name='1'></a>

# %% [raw]
# !pip install xmlschema
# !pip install psycopg2

# %%
import xmlschema
from pprint import pprint
import psycopg2
from psycopg2 import OperationalError
from psycopg2.errors import ForeignKeyViolation
import os

# %% [markdown]
# ### Загрузка файлов <a name='2'></a>

# %%
# название файла с xsd-схемой и локальный путь к нему
schema_file = 'structure-20201220.xsd'
schema = xmlschema.XMLSchema(schema_file)

# %%
# создадим список с локальными путями к 150 файлам из датасета
file_directory = 'data/'

folder = []
for i in os.walk(file_directory):
    folder.append(i)

# %%
address_list = []
for address, dirs, files in folder:
    for file in files[:150]:
        address_list.append(address + file)

print('Количество файлов: {}'.format(len(address_list)))
# Out:
# Количество файлов: 150

# %% [markdown]
# ### Валидация xml-файлов и xsd-схемы <a name='3'></a>

# %% [markdown]
# В процессе первичной валидации xml-файлов было обнаружино общее несоответствие в xsd-схеме:
# не хватало блока информации "ВидСуб" в схеме, который присутствовал во всех файлах. После добавления в схему этого блока проблема исчезла.
#
# Были взяты 150 файлов из архива и проверенв на соответствие схеме для дальнейшей работы с ними:

# %%
error = 0
for xml in address_list:
    if schema.is_valid(xml):
        continue
    else:
        error += 1

print('Количество ошибок: {} \nКоличество проверенных файлов: {}'
      .format(error, len(address_list)))
# Out:
# Количество ошибок: 0
# Количество проверенных файлов: 150

# %% [markdown]
# ### Визуальное знакомство со структурой полученных файлов <a name=‘4’></a>

# %%
data_dict = schema.to_dict(file_xml)
pprint(data_dict.keys())
# Out:
# dict_keys(['@ИдФайл', '@ВерсФорм', '@ТипИнф', '@КолДок', 'ИдОтпр', 'Документ'])

# %%
pprint(data_dict['Документ'][9])
# Out:
# {'@ВидСуб': '2',
#  '@ДатаСост': '18.12.2020',
#  '@ИдДок': 'a38e7782-dc88-49f8-b85f-1ba270bc1674',
#  'СвПредПод': [{'@ВидПП': '2',
#                 '@ДатаПрин': '11.06.2020',
#                 '@ИННЮЛ': '7707329152',
#                 '@КатСуб': '2',
#                 '@НаимОрг': 'ФЕДЕРАЛЬНАЯ НАЛОГОВАЯ СЛУЖБА',
#                 '@СрокПод': '11.06.2020',
#                 'ВидПод': {'@КодВид': '0103',
#                            '@НаимВид': 'Предоставление субсидий и грантов'},
#                 'ИнфНаруш': {'@ИнфНаруш': '2', '@ИнфНецел': '2'},
#                 'РазмПод': [{'@ЕдПод': '1', '@РазмПод': Decimal('303250.00')}],
#                 'ФормПод': {'@КодФорм': '0100',
#                             '@НаимФорм': 'Финансовая поддержка'}},
#                {'@ВидПП': '2',
#                 '@ДатаПрин': '20.05.2020',
#                 '@ИННЮЛ': '7707329152',
#                 '@КатСуб': '2',
#                 '@НаимОрг': 'ФЕДЕРАЛЬНАЯ НАЛОГОВАЯ СЛУЖБА',
#                 '@СрокПод': '20.05.2020',
#                 'ВидПод': {'@КодВид': '0103',
#                            '@НаимВид': 'Предоставление субсидий и грантов'},
#                 'ИнфНаруш': {'@ИнфНаруш': '2', '@ИнфНецел': '2'},
#                 'РазмПод': [{'@ЕдПод': '1', '@РазмПод': Decimal('303250.00')}],
#                 'ФормПод': {'@КодФорм': '0100',
#                             '@НаимФорм': 'Финансовая поддержка'}},
#                {'@ВидПП': '2',
#                 '@ДатаПрин': '29.07.2020',
#                 '@ИННЮЛ': '7707329152',
#                 '@КатСуб': '2',
#                 '@НаимОрг': 'ФЕДЕРАЛЬНАЯ НАЛОГОВАЯ СЛУЖБА',
#                 '@СрокПод': '29.07.2020',
#                 'ВидПод': {'@КодВид': '0103',
#                            '@НаимВид': 'Предоставление субсидий и грантов'},
#                 'ИнфНаруш': {'@ИнфНаруш': '2', '@ИнфНецел': '2'},
#                 'РазмПод': [{'@ЕдПод': '1', '@РазмПод': Decimal('164500.00')}],
#                 'ФормПод': {'@КодФорм': '0100',
#                             '@НаимФорм': 'Финансовая поддержка'}}],
#  'СвФЛ': {'@ИННФЛ': '381251791888',
#           'ФИО': {'@Имя': 'ОСТРОВСКИЙ МАКСИМ СЕРГЕЕВИЧ',
#                   '@Отчество': 'ОСТРОВСКИЙ МАКСИМ СЕРГЕЕВИЧ',
#                   '@Фамилия': 'ОСТРОВСКИЙ МАКСИМ СЕРГЕЕВИЧ'}}}

# %% [markdown]
# В полученных файлах присутствуют несколько ключей, но необходимая нам информация находится по ключевому слову "Документ".

# %% [markdown]
# ## Архитектура БД в PostgreSQL <a name='0.1'></a>

# %% [markdown]
# ### Подключение к Базе данных PostgreSQL <a name='5'></a>

# %% [markdown]
# Для подключения базе данных необходимо ввести наименование БД, имя пользователя и пароль, адрес сервера и номер порта для переменной:

# %%
connect = psycopg2.connect(
    database='cpur',
    user='cpur',
    password='cpur',
    host='localhost',
    port=5432,
)

# %% [markdown]
# Функция для упрощения процесса отправки запросов к БД:

# %%
def execute_query(connection, query):
    '''
    Функция принимает:
    connection — объект подключения, представляющий базу данных,
    query — запрос к базе данных. Автокоммит включен.
    
    Возвращает информацию о статусе выполнения запроса.
    '''
    connection.autocommit = True
    cursor = connection.cursor()
    cursor.execute(query)

# %% [markdown]
# ### Описание структуры БД <a name='6'></a>

# %% [markdown]
# ![](http://dl3.joxi.net/drive/2021/01/22/0043/3666/2862674/74/4891f85cff.png)
#
# Данные хранятся в 4 таблицах, связанных между собой ([ссылка на схему](http://dl3.joxi.net/drive/2021/01/22/0043/3666/2862674/74/4891f85cff.png)):
# * в таблице `entity` хранятся данные о получателях подддержки,
# * в таблице `institution` хранятся данные об органах, предоставляющих поддержку,
# * в таблице `support` собранны данные о видах и подвидах оказываемой поддержки согласно словарю СФВРМСП-ПП,
# * в таблице `request` хранятся данные о текущем статусе запросов на поддержку, количестве и виде поддержки, а также дополнительная информация о получателях поддержки и налии правонарушений.

# %% [markdown]
# ### Создание необходимых таблиц в Базе данных <a name='7'></a>

# %% [markdown]
# Создадим необходимую архитектуру БД перед началом работы. Для запуска запроса к БД необходимо убрать коммит ячейки и перезапустить код.

# %%
create_entity_table = '''
CREATE TABLE entity (
    entity_inn VARCHAR(12) PRIMARY KEY,
    company VARCHAR(1000),
    full_name VARCHAR(180)
)
'''

# %%
#execute_query(connect, create_entity_table)

# %%
create_state_support_table = '''
CREATE TABLE institution (
    institution_inn VARCHAR(12) PRIMARY KEY,
    company VARCHAR(1000)
)
'''

# %%
#execute_query(connect, create_state_support_table)

# %%
create_type_support_table = '''
CREATE TABLE support (
    type_id VARCHAR(4) PRIMARY KEY,
    name_type VARCHAR(200) NOT NULL,
    form_id VARCHAR(4) NOT NULL,
    name_form VARCHAR(100) NOT NULL
)
'''

# %%
#execute_query(connect, create_type_support_table)

# %%
create_request_support_table = '''
CREATE TABLE request (
    id_request SERIAL PRIMARY KEY,
    entity_inn VARCHAR(12) REFERENCES entity (entity_inn),
    entity_type INTEGER,
    entity_category INTEGER,
    institution_inn VARCHAR(10) REFERENCES institution (institution_inn),
    action_type VARCHAR(4) REFERENCES support(type_id),
    start_date DATE,
    plan_date DATE,
    stop_date DATE,
    cost DECIMAL,
    cost_unit INTEGER,
    offence INTEGER,
    misuse INTEGER,
    
    CONSTRAINT unit_min_max CHECK (cost_unit > 0 AND cost_unit <= 5),
    CONSTRAINT offence_min_max CHECK (offence > 0 AND offence <= 2),
    CONSTRAINT misuse_min_max CHECK (misuse > 0 AND misuse <= 2),
    CONSTRAINT type_min_max CHECK (entity_type > 0 AND entity_type <= 3),
    CONSTRAINT category_min_max CHECK (entity_category > 0 AND entity_category <= 4)
)
'''

# %%
#execute_query(connect, create_request_support_table)

# %% [markdown]
# ## Подготовка и парсинг данных в Базу данных <a name='0.2'></a>

# %% [markdown]
# ### Функции для запросов на добавление данных в БД <a name='8'></a>

# %%
class UserInfo:
    def __init__(self, document):
        if 'СвФЛ' in document:
            self.entity_inn = document['СвФЛ']['@ИННФЛ']
            self.name = document['СвФЛ']['ФИО']['@Фамилия']
            self.company = None
        else:
            self.entity_inn = document['СвЮЛ']['@ИННЮЛ']
            self.company = document['СвЮЛ']['@НаимОрг'].replace("'", '')
            self.name = None
            
def add_inn_info(user_info):
    '''
    Функция отправляет запрос к БД PostgreSQL и добавляет общую информацию
    о получателе поддержки в таблицу "entity". 
    Дублирующиеся значения по первичному ключу "entity_inn" игнорируются.
    '''
    if user_info.company is None:
        execute_query(connect, "INSERT INTO entity\
                               (entity_inn, full_name)\
                                VALUES {} \
                                ON CONFLICT (entity_inn) DO NOTHING"
                      .format((user_info.entity_inn, user_info.name)))
    else:
        execute_query(connect, "INSERT INTO entity\
                               (entity_inn, company)\
                                VALUES {} \
                                ON CONFLICT (entity_inn) DO NOTHING"
                      .format((user_info.entity_inn, user_info.company)))

# %%
def add_inn_institution(institution_inn, company):
    '''
    Функция отправляет запрос к БД PostgreSQL и добавляет общую информацию
    об органах, предоставляющих поддержку в таблицу "institution". 
    Дублирующиеся значения по первичному ключу "institution_inn" игнорируются.
    '''
    execute_query(connect, "INSERT INTO institution\
                           (institution_inn, company)\
                            VALUES {} \
                            ON CONFLICT (institution_inn) DO NOTHING"
                  .format((institution_inn, company)))

# %%
def add_support_type(type_id, name_type, form_id, name_form):
    '''
    Функция отправляет запрос к БД PostgreSQL и добавляет общую информацию
    о типах предоставляемой поддержки в таблицу "support". 
    Дублирующиеся значения по первичному ключу "type_id" игнорируются.
    '''
    execute_query(connect, "INSERT INTO support\
                           (type_id, name_type, form_id, name_form)\
                            VALUES {} \
                            ON CONFLICT (type_id) DO NOTHING"
                  .format((type_id, name_type, form_id, name_form)))

# %%
def to_ps_date(date):
    d, m, y = date.split(".")
    return "-".join((y, m, d))

def add_request_info(entity_inn, entity_type, entity_category, institution_inn, action_type,
                     start_date, plan_date, stop_date, cost, cost_unit, offence, misuse):
    '''
    Функция отправляет запрос к БД PostgreSQL и добавляет информацию
    о поступивших запросах в таблицу "request". Каждой записи присваивается
    уникальное значение-ключ "id_request"
    '''
    req_template = "INSERT INTO request\
                           (entity_inn, entity_type, entity_category,\
                            institution_inn, action_type,\
                            start_date, plan_date,"
    params = [entity_inn, entity_type, entity_category, institution_inn,
                          action_type, to_ps_date(start_date), to_ps_date(plan_date)]
    if stop_date:
        req_template += "stop_date,"
        params.append(to_ps_date(stop_date))
    
    req_template += "cost, cost_unit, offence, misuse) VALUES {}"
    params += [str(cost), cost_unit, offence, misuse]
    try:
        execute_query(connect, req_template.format(tuple(params)))
    except ForeignKeyViolation as e:
        print(e)

# %% [markdown]
# ### Функции для парсинга данных из xml-файлов и добавления их в БД <a name='9'></a>

# %%
# данные о получателях поддержки
def save_user(document):
    user = UserInfo(document)
    add_inn_info(user)

# %%
# данные о видах оказываемой поддержки
def save_type_support(document):
    support = document['СвПредПод']
    for item in support:
        type_id = item['ВидПод']['@КодВид']
        name_type = item['ВидПод']['@НаимВид']
        form_id = item['ФормПод']['@КодФорм']
        name_form = item['ФормПод']['@НаимФорм']
        add_support_type(type_id, name_type, form_id, name_form)

# %%
# данные о запросах на оказание поддержки
def save_request(document):
    request = document['СвПредПод']
    entity_inn = UserInfo(document).entity_inn
    for item in request:
        entity_type = item['@ВидПП']
        entity_category = item['@КатСуб']
        institution_inn = item['@ИННЮЛ']
        action_type = item['ВидПод']['@КодВид']
        start_date = item['@ДатаПрин']
        plan_date = item['@СрокПод'] 
        cost = item['РазмПод'][0]['@РазмПод']
        cost_unit = item['РазмПод'][0]['@ЕдПод']
        offence = item['ИнфНаруш']['@ИнфНаруш']
        misuse = item['ИнфНаруш']['@ИнфНецел']
        if '@ДатаПрекр' in item:
            stop_date = item['@ДатаПрекр']
        else:
            stop_date = None
    
        add_request_info(entity_inn, entity_type, entity_category, institution_inn, 
                         action_type, start_date, plan_date, stop_date, cost, 
                         cost_unit, offence, misuse)

# %%
# данные об органах, предоставляющих поддержку
def save_institution(document):
    institution = document['СвПредПод']
    for item in institution:
        institution_inn = item['@ИННЮЛ']
        company = item['@НаимОрг']
    
    add_inn_institution(institution_inn, company)

# %% [markdown]
# ### Парсинг данных из xlm-файлов в БД <a name='10'></a>

# %%
for xml in address_list:
    data_dict = schema.to_dict(xml)
    for doc in data_dict['Документ']:
        save_type_support(doc)

# %%
for xml in address_list:
    data_dict = schema.to_dict(xml)
    for doc in data_dict['Документ']:
        save_user(doc)

# %%
for xml in address_list:
    data_dict = schema.to_dict(xml)
    for doc in data_dict['Документ']:
        save_institution(doc)

# %% [markdown]
# При парсинге запросов на поддержку в таблицу `request` ряд строк для повторяющихся ИНН организаций, оказывающих поддержку, не получилось обработать. При создании итоговой версии Базы данных на это необходимо обратить внимание и выявить проблему. На данном этапе мы собрали ряд отчетов об ошибке, из которых можно будет взять необходимую информацию и провести с ее помощью ресерч проблемы.

# %%
for xml in address_list:
    data_dict = schema.to_dict(xml)
    for doc in data_dict['Документ']:
        save_request(doc)
# Out:
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4701001377) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4708007427) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4708007427) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5252030901) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2983010493) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2983010493) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2983010493) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2983010493) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5260420574) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5248040664) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5248040664) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5248040664) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5248040664) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5248040664) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1435175512) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1435175512) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1404005800) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1404005800) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1404005800) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1404005800) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1404005800) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1404005800) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1404005800) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1404005800) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4712039407) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4707025303) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4707025303) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6027180150) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6027180150) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4707040904) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0405003497) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4319002842) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4319002842) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4319002842) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4319002842) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4319002842) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4319002842) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4319002842) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4319002842) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4320002396) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1901090185) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4705031044) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4719011785) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4705031044) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4719011785) is not present in table "institution".
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3728013000) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3728013000) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3728013000) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3728013000) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5260420574) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9102183021) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9102011897) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1652011818) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5902993324) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7303006082) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1637000226) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1637000226) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1637000226) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1637000226) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1637000226) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7325050230) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1513065943) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1506003030) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8617011350) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1502023684) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4708007427) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7009001530) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1638004985) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1655271099) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1655271099) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5826100255) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6234188542) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6227000292) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0105981150) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8601028125) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2636089456) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2636089456) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2327004864) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8901023569) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8901023569) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3651999042) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3616999089) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5503047244) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2221129510) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2221129510) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2221129510) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2221129510) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5503047244) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5522006148) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5522006148) is not present in table "institution".
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5503081005) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5503047244) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5503047244) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2528885651) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2721222733) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2721222733) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2511004094) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4707040904) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5101000398) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5101000398) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5104001992) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5190021206) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5190021206) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5190021206) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5190021206) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5190021206) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5191110307) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3444153572) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3444153572) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3444030098) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3442007544) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3445915417) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3446500895) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3443907731) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1435175512) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2353011258) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2353011258) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2632071754) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2636212533) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8001004443) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0308003029) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7704253064) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2502012187) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2326007654) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4707025303) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4707025303) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6136003842) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6136003842) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6164259476) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9204014946) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9106002621) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7024009277) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7017297970) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7017297970) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3015028318) is not present in table "institution".
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5836013675) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1640003883) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1640003883) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1643007798) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1654022036) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1655306513) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1655271099) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1655271099) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1655271099) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5514003009) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5510002276) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5503047244) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5503047244) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5503047244) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5503047244) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5503047244) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5535006339) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6686996023) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6686996023) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6686996023) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6508003210) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1001041065) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2333011210) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3728012487) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2377002005) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4710026201) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6017004163) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4719011785) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4719011785) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3436102623) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3436102623) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3436102623) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0275913140) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0275913140) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6807001194) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9204014946) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9204014946) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9204014946) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9204002771) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9204014946) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9204014946) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3013000518) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8901023569) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8901023569) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4707025303) is not present in table "institution".
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1813000930) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1601005936) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1601005936) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5260420574) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5205995010) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6668021088) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6163207186) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7106071692) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4719011785) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7106071692) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7104520110) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6121903583) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6139003671) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1101205870) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1101205870) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1101205870) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3122014856) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3504001168) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3526008696) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3444201811) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6163021632) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1205000518) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1215109137) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1205000518) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1205000518) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1215109137) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1207002292) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3519000921) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2308077000) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2308077000) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7606009396) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7606009396) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7606009396) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7623000516) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7623000516) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7611002653) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7604016214) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7604016214) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7604016214) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7604016214) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7604016214) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7604016214) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2433000741) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6801002152) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9108009213) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9105003502) is not present in table "institution".
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(9105003502) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0258010691) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0258010684) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5260420574) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5902993324) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2906002459) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1615000448) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2636089456) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6918000647) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5306000656) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5110120236) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1001041065) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4809001742) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4815000698) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6510003232) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6506008220) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6510003232) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1642004466) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2116820246) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2116820246) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8617011350) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8617011350) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5948001678) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5948024308) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5948024308) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5703008891) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7116129736) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6226010611) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6226010611) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7116129736) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7116129736) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0274933640) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0201008497) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7453313646) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7453313646) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7453313646) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7453313646) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5432211449) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5432211449) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2225050251) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2221129510) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6686996023) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6606011805) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6681006804) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6681006804) is not present in table "institution".
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6606011805) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2801226420) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5433107553) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0275913140) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8901023569) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2354005874) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3704001084) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5260420574) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5260420574) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5260420574) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3724002463) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3724002463) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3728015495) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3724002463) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3724002463) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3724002463) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3724002463) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4025078327) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1435175512) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1411003560) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1435108467) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(1435108467) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(4703083640) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(0814055440) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6142005365) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(6142005365) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3444067813) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(3436102623) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7203236163) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7203236163) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(2377002005) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(5419000030) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(8601999102) is not present in table "institution".
#
# insert or update on table "request" violates foreign key constraint "request_institution_inn_fkey"
# DETAIL:  Key (institution_inn)=(7606009396) is not present in table "institution".

# %%
# завершение подключения к Базе данных
connect.close()
